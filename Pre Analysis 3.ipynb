# %%
import pandas as pd
import os

# %%
#list content in folder, if csv
files = [x for x in os.listdir('data') if x.endswith('.csv')]
for filename in files:
    print(filename)
# Out:
# AAPL-edited.csv
# AAPL.csv
# AMZN-edited.csv
# AMZN.csv
# BCHAIN-NEW.csv
# BTC-USD.csv
# EOD-DIS-edited.csv
# EOD-DIS.csv
# EOD-MMM-edited.csv
# EOD-MMM.csv
# EOD-MSFT-edited.csv
# EOD-MSFT.csv
# EOD-V-edited.csv
# EOD-V.csv
# FB-edited.csv
# FB.csv
# GOOG-edited.csv
# GOOG.csv
# NFLX-edited.csv
# NFLX.csv
# TSLA-edited.csv
# TSLA.csv

# %%
df = pd.read_csv('data/BTC-USD.csv')
df.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close  Volume
# 0  2010-07-16  0.04951  0.04951  0.04951  0.04951    0.04951       0
# 1  2010-07-17  0.04951  0.08585  0.05941  0.08584    0.08584       5
# 2  2010-07-18  0.08584  0.09307  0.07723  0.08080    0.08080      49
# 3  2010-07-19  0.08080  0.08181  0.07426  0.07474    0.07474      20
# 4  2010-07-20  0.07474  0.07921  0.06634  0.07921    0.07921      42

# %%
def count_drop(numbers):
    return len([x for x in numbers if x < 0])

def count_up(numbers):
    return len([x for x in numbers if x > 0])

# Date        Value USD   Value 2     Max 7       Min 7       Change     Mean Change 7      Drop 7  Up 7    Predict
#2010-08-02 	0.06000 	0.06500 	0.05900 	0.06000 	0.06000 	606 	0.06000 	0.06990 	0.0589 	0.00000 	0.000000 	2.0 	4.0 	NaN
#2010-09-05 	0.06160 	0.06270 	0.06160 	0.06160 	0.06160 	56 	0.06160 	0.06497 	0.0600 	0.00000 	0.000481 	3.0 	3.0 	NaN
#2010-12-23 	0.25000 	0.25000 	0.24100 	0.25000 	0.25000 	2160 	0.25000 	0.26700 	0.2400 	0.00000 	0.000000 	3.0 	3.0 	NaN
#2010-12-27 	0.26500 	0.27000 	0.25100 	0.26500 	0.26500 	1270 	0.26500 	0.26700 	0.2400 	0.00000 	0.000286 	3.0 	2.0 	NaN

def decider(row):
    if row['Drop 7'] < row['Up 7'] and row['Mean Change 7'] > 0 and row['Change'] >= 0:
        return 1
    elif row['Drop 7'] > row['Up 7'] and row['Mean Change 7'] < 0 and row['Change'] >= 0:
        return 0
    elif row['Drop 7'] < row['Up 7'] and row['Mean Change 7'] > 0 or row['Change'] >= 0:
        return -1
    elif row['Drop 7'] < row['Up 7'] and row['Mean Change 7'] < 0 or row['Change'] < 0:
        return -2
    elif row['Drop 7'] < row['Up 7'] and row['Mean Change 7'] > 0 and row['Change'] < 0:
        return -3
    elif row['Drop 7'] > row['Up 7'] and row['Mean Change 7'] < 0 and row['Change'] < 0:
        return -4

#df.rename(columns={'Value': 'Value USD'}, inplace=True)
df['Open 2'] = df['Open'].shift(-1)
df['Max 7'] = df['Open'].rolling(7).max()
df['Min 7'] = df['Open'].rolling(7).min()
df['Change'] = df['Open'] - df['Open 2']
df['Mean Change 7'] = df['Change'].rolling(7).mean()
df['Drop 7'] = df['Change'].rolling(7).apply(count_drop)
df['Up 7'] = df['Change'].rolling(7).apply(count_up)
df['Predict'] = df.apply(decider, axis=1)

# %%
def count_drop(numbers):
    return len([x for x in numbers if x < 0])

def count_up(numbers):
    return len([x for x in numbers if x > 0])

# Date        Value USD   Value 2     Max 7       Min 7       Change     Mean Change 7      Drop 7  Up 7    Predict
#2010-08-02 	0.06000 	0.06500 	0.05900 	0.06000 	0.06000 	606 	0.06000 	0.06990 	0.0589 	0.00000 	0.000000 	2.0 	4.0 	NaN
#2010-09-05 	0.06160 	0.06270 	0.06160 	0.06160 	0.06160 	56 	0.06160 	0.06497 	0.0600 	0.00000 	0.000481 	3.0 	3.0 	NaN
#2010-12-23 	0.25000 	0.25000 	0.24100 	0.25000 	0.25000 	2160 	0.25000 	0.26700 	0.2400 	0.00000 	0.000000 	3.0 	3.0 	NaN
#2010-12-27 	0.26500 	0.27000 	0.25100 	0.26500 	0.26500 	1270 	0.26500 	0.26700 	0.2400 	0.00000 	0.000286 	3.0 	2.0 	NaN

def decider(row):
    if row['Drop 7'] < row['Up 7'] and row['Mean Change 7'] > 0 and row['Change'] >= 0:
        return 1
    elif row['Drop 7'] > row['Up 7'] and row['Mean Change 7'] < 0 and row['Change'] >= 0:
        return 0
    elif row['Drop 7'] < row['Up 7'] and row['Mean Change 7'] > 0 or row['Change'] >= 0:
        return -1
    elif row['Drop 7'] < row['Up 7'] and row['Mean Change 7'] < 0 or row['Change'] < 0:
        return -2
    elif row['Drop 7'] < row['Up 7'] and row['Mean Change 7'] > 0 and row['Change'] < 0:
        return -3
    elif row['Drop 7'] > row['Up 7'] and row['Mean Change 7'] < 0 and row['Change'] < 0:
        return -4

# %%
df.head(10)
# Out:
#          Date     Open     High      Low    Close  Adj Close  Volume   Open 2  \
# 0  2010-07-16  0.04951  0.04951  0.04951  0.04951    0.04951       0  0.04951
# 1  2010-07-17  0.04951  0.08585  0.05941  0.08584    0.08584       5  0.08584
# 2  2010-07-18  0.08584  0.09307  0.07723  0.08080    0.08080      49  0.08080
# 3  2010-07-19  0.08080  0.08181  0.07426  0.07474    0.07474      20  0.07474
# 4  2010-07-20  0.07474  0.07921  0.06634  0.07921    0.07921      42  0.07921
# 5  2010-07-21  0.07921  0.08181  0.05050  0.05050    0.05050     129  0.05050
# 6  2010-07-22  0.05050  0.06767  0.05050  0.06262    0.06262     141  0.06262
# 7  2010-07-23  0.06262  0.06161  0.05049  0.05454    0.05454      26  0.05454
# 8  2010-07-24  0.05454  0.05941  0.05050  0.05050    0.05050      85  0.05050
# 9  2010-07-25  0.05050  0.05600  0.05000  0.05600    0.05600      46  0.05600
#
#      Max 7    Min 7   Change  Mean Change 7  Drop 7  Up 7  Predict
# ...

# %%
df.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 2955  2018-08-18  6405.740234  6560.879883  6330.560059  6502.180176
# 2956  2018-08-19  6502.240234  6537.540039  6248.390137  6269.899902
# 2957  2018-08-20  6270.089844  6506.689941  6259.810059  6491.109863
# 2958  2018-08-21  6491.089844  6890.790039  6264.339844  6366.129883
# 2959  2018-08-22  6366.140137  6575.279785  6356.959961  6538.950195
#
#         Adj Close     Volume       Open 2        Max 7        Min 7  \
# 2955  6502.180176  253984821  6502.240234  6591.180176  6199.629883
# 2956  6269.899902  397981291  6270.089844  6591.180176  6199.629883
# 2957  6491.109863  396746063  6491.089844  6591.180176  6199.629883
# 2958  6366.129883  764005011  6366.140137  6591.180176  6270.089844
# 2959  6538.950195  340811486          NaN  6591.180176  6270.089844
#
#           Change  Mean Change 7  Drop 7  Up 7  Predict
# 2955  -96.500000     -25.690011     4.0   3.0     -2.0
# ...

# %%
df[df.isnull().any(axis=1)].head(10)
# Out:
#             Date         Open         High          Low        Close  \
# 0     2010-07-16     0.049510     0.049510     0.049510     0.049510
# 1     2010-07-17     0.049510     0.085850     0.059410     0.085840
# 2     2010-07-18     0.085840     0.093070     0.077230     0.080800
# 3     2010-07-19     0.080800     0.081810     0.074260     0.074740
# 4     2010-07-20     0.074740     0.079210     0.066340     0.079210
# 5     2010-07-21     0.079210     0.081810     0.050500     0.050500
# 2959  2018-08-22  6366.140137  6575.279785  6356.959961  6538.950195
#
#         Adj Close     Volume   Open 2        Max 7        Min 7   Change  \
# 0        0.049510          0  0.04951          NaN          NaN  0.00000
# 1        0.085840          5  0.08584          NaN          NaN -0.03633
# 2        0.080800         49  0.08080          NaN          NaN  0.00504
# 3        0.074740         20  0.07474          NaN          NaN  0.00606
# ...

# %%
df.dropna(subset=['Max 7', 'Min 7', 'Mean Change 7', 'Drop 7', 'Up 7'], inplace=True)

# %%
df[df.isnull().any(axis=1)].head(10)
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume, Open 2, Max 7, Min 7, Change, Mean Change 7, Drop 7, Up 7, Predict]
# Index: []

# %%
df.head()
# Out:
#           Date     Open     High      Low    Close  Adj Close  Volume  \
# 6   2010-07-22  0.05050  0.06767  0.05050  0.06262    0.06262     141
# 7   2010-07-23  0.06262  0.06161  0.05049  0.05454    0.05454      26
# 8   2010-07-24  0.05454  0.05941  0.05050  0.05050    0.05050      85
# 9   2010-07-25  0.05050  0.05600  0.05000  0.05600    0.05600      46
# 10  2010-07-26  0.05600  0.06050  0.05300  0.06000    0.06000     196
#
#      Open 2    Max 7    Min 7   Change  Mean Change 7  Drop 7  Up 7  Predict
# 6   0.06262  0.08584  0.04951 -0.01212      -0.001873     3.0   3.0     -2.0
# 7   0.05454  0.08584  0.04951  0.00808      -0.000719     3.0   4.0     -1.0
# 8   0.05050  0.08584  0.05050  0.00404       0.005049     2.0   5.0      1.0
# 9   0.05600  0.08080  0.05050 -0.00550       0.003543     3.0   4.0     -1.0
# 10  0.06000  0.07921  0.05050 -0.00400       0.002106     4.0   3.0     -2.0

# %%
def prediction(value):
    if value > 0:
        return 1
    return 0

def actual_calc(row):
    if row['Open'] > row['Adj Close']:
        return 0
    return 1

# %%
df['Prediction'] = df['Predict'].apply(prediction)
df.head()
# Out:
#           Date     Open     High      Low    Close  Adj Close  Volume  \
# 6   2010-07-22  0.05050  0.06767  0.05050  0.06262    0.06262     141
# 7   2010-07-23  0.06262  0.06161  0.05049  0.05454    0.05454      26
# 8   2010-07-24  0.05454  0.05941  0.05050  0.05050    0.05050      85
# 9   2010-07-25  0.05050  0.05600  0.05000  0.05600    0.05600      46
# 10  2010-07-26  0.05600  0.06050  0.05300  0.06000    0.06000     196
#
#      Open 2    Max 7    Min 7   Change  Mean Change 7  Drop 7  Up 7  Predict  \
# 6   0.06262  0.08584  0.04951 -0.01212      -0.001873     3.0   3.0     -2.0
# 7   0.05454  0.08584  0.04951  0.00808      -0.000719     3.0   4.0     -1.0
# 8   0.05050  0.08584  0.05050  0.00404       0.005049     2.0   5.0      1.0
# 9   0.05600  0.08080  0.05050 -0.00550       0.003543     3.0   4.0     -1.0
# 10  0.06000  0.07921  0.05050 -0.00400       0.002106     4.0   3.0     -2.0
#
#     Prediction
# 6            0
# 7            0
# 8            1
# ...

# %%
df['Actual'] = df.apply(actual_calc, axis=1)
df.head()
# Out:
#           Date     Open     High      Low    Close  Adj Close  Volume  \
# 6   2010-07-22  0.05050  0.06767  0.05050  0.06262    0.06262     141
# 7   2010-07-23  0.06262  0.06161  0.05049  0.05454    0.05454      26
# 8   2010-07-24  0.05454  0.05941  0.05050  0.05050    0.05050      85
# 9   2010-07-25  0.05050  0.05600  0.05000  0.05600    0.05600      46
# 10  2010-07-26  0.05600  0.06050  0.05300  0.06000    0.06000     196
#
#      Open 2    Max 7    Min 7   Change  Mean Change 7  Drop 7  Up 7  Predict  \
# 6   0.06262  0.08584  0.04951 -0.01212      -0.001873     3.0   3.0     -2.0
# 7   0.05454  0.08584  0.04951  0.00808      -0.000719     3.0   4.0     -1.0
# 8   0.05050  0.08584  0.05050  0.00404       0.005049     2.0   5.0      1.0
# 9   0.05600  0.08080  0.05050 -0.00550       0.003543     3.0   4.0     -1.0
# 10  0.06000  0.07921  0.05050 -0.00400       0.002106     4.0   3.0     -2.0
#
#     Prediction  Actual
# 6            0       1
# 7            0       0
# ...

# %%
df[df['Prediction'] != df['Actual']]
# Out:
#             Date         Open         High          Low        Close  \
# 6     2010-07-22     0.050500     0.067670     0.050500     0.062620
# 8     2010-07-24     0.054540     0.059410     0.050500     0.050500
# 9     2010-07-25     0.050500     0.056000     0.050000     0.056000
# 10    2010-07-26     0.056000     0.060500     0.053000     0.060000
# 11    2010-07-27     0.060000     0.062000     0.054000     0.058900
# 12    2010-07-28     0.058900     0.069900     0.057100     0.069900
# 14    2010-07-30     0.062700     0.068890     0.056000     0.067850
# 17    2010-08-02     0.060000     0.065000     0.059000     0.060000
# 18    2010-08-03     0.060000     0.062310     0.057000     0.057000
# 19    2010-08-04     0.057000     0.061000     0.058000     0.061000
# 20    2010-08-05     0.061000     0.062400     0.060700     0.062300
# 21    2010-08-06     0.062300     0.062200     0.059000     0.059000
# 22    2010-08-07     0.059000     0.061000     0.059000     0.060900
# ...

# %%
df[df['Prediction'] != df['Actual']].shape
# Out:
# (2218, 17)

# %%
df.shape
# Out:
# (2953, 17)

# %%
df.head(10)
# Out:
#           Date     Open     High      Low    Close  Adj Close  Volume  \
# 6   2010-07-22  0.05050  0.06767  0.05050  0.06262    0.06262     141
# 7   2010-07-23  0.06262  0.06161  0.05049  0.05454    0.05454      26
# 8   2010-07-24  0.05454  0.05941  0.05050  0.05050    0.05050      85
# 9   2010-07-25  0.05050  0.05600  0.05000  0.05600    0.05600      46
# 10  2010-07-26  0.05600  0.06050  0.05300  0.06000    0.06000     196
# 11  2010-07-27  0.06000  0.06200  0.05400  0.05890    0.05890     255
# 12  2010-07-28  0.05890  0.06990  0.05710  0.06990    0.06990     528
# 13  2010-07-29  0.06990  0.06980  0.05820  0.06270    0.06270     198
# 14  2010-07-30  0.06270  0.06889  0.05600  0.06785    0.06785     243
# 15  2010-07-31  0.06785  0.06500  0.06000  0.06110    0.06110     162
#
#      Open 2    Max 7    Min 7   Change  Mean Change 7  Drop 7  Up 7  Predict  \
# 6   0.06262  0.08584  0.04951 -0.01212      -0.001873     3.0   3.0     -2.0
# ...

# %%
df.to_csv('data/BTC-USD-edited.csv', index=False)

# %%
df2 = pd.read_csv('data/AAPL.csv')
df2.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.023186  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.021977   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.020364   26432000.0
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.020868   21610400.0
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.021473   18362400.0

# %%
df2['Open 2'] = df2['Open'].shift(-1)
df2['Max 7'] = df2['Open'].rolling(7).max()
df2['Min 7'] = df2['Open'].rolling(7).min()
df2['Change'] = df2['Open'] - df2['Open 2']
df2['Mean Change 7'] = df2['Change'].rolling(7).mean()
df2['Drop 7'] = df2['Change'].rolling(7).apply(count_drop)
df2['Up 7'] = df2['Change'].rolling(7).apply(count_up)
df2['Predict'] = df2.apply(decider, axis=1)
df2['Prediction'] = df2['Predict'].apply(prediction)
df2['Actual'] = df2.apply(actual_calc, axis=1)
df2.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.023186  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.021977   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.020364   26432000.0
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.020868   21610400.0
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.021473   18362400.0
#
#      Open 2  Max 7  Min 7    Change  Mean Change 7  Drop 7  Up 7  Predict  \
# 0  0.488839    NaN    NaN  0.024554            NaN     NaN   NaN     -1.0
# 1  0.453125    NaN    NaN  0.035714            NaN     NaN   NaN     -1.0
# 2  0.462054    NaN    NaN -0.008929            NaN     NaN   NaN     -2.0
# 3  0.475446    NaN    NaN -0.013392            NaN     NaN   NaN     -2.0
# 4  0.504464    NaN    NaN -0.029018            NaN     NaN   NaN     -2.0
#
#    Prediction  Actual
# 0           0       0
# ...

# %%
df2.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.023186  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.021977   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.020364   26432000.0
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.020868   21610400.0
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.021473   18362400.0
# 5  1980-12-19  0.504464  0.506696  0.504464  0.504464   0.022783   12157600.0
# 6  1980-12-22  0.529018  0.531250  0.529018  0.529018   0.023892    9340800.0
# 7  1980-12-23  0.551339  0.553571  0.551339  0.551339   0.024900   11737600.0
# 8  1980-12-24  0.580357  0.582589  0.580357  0.580357   0.026211   12000800.0
# 9  1980-12-26  0.633929  0.636161  0.633929  0.633929   0.028630   13893600.0
#
#      Open 2     Max 7     Min 7    Change  Mean Change 7  Drop 7  Up 7  \
# ...

# %%
df2[df2['Prediction'] != df2['Actual']].shape
# Out:
# (2390, 17)

# %%
df2.shape
# Out:
# (9497, 17)

# %%
df2.to_csv('data/AAPL-edited2.csv', index=False)

# %%
df2.dropna(subset=['Max 7', 'Min 7', 'Mean Change 7', 'Drop 7', 'Up 7'], inplace=True)

# %%
df2[df2.isnull().any(axis=1)].head(10)
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume, Open 2, Max 7, Min 7, Change, Mean Change 7, Drop 7, Up 7, Predict, Prediction, Actual]
# Index: []

# %%
df3 = pd.read_csv('data/AMZN.csv')
df3.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083   1.427083  18853200

# %%
df3['Open 2'] = df3['Open'].shift(-1)
df3['Max 7'] = df3['Open'].rolling(7).max()
df3['Min 7'] = df3['Open'].rolling(7).min()
df3['Change'] = df3['Open'] - df3['Open 2']
df3['Mean Change 7'] = df3['Change'].rolling(7).mean()
df3['Drop 7'] = df3['Change'].rolling(7).apply(count_drop)
df3['Up 7'] = df3['Change'].rolling(7).apply(count_up)
df3['Predict'] = df3.apply(decider, axis=1)
df3['Prediction'] = df3['Predict'].apply(prediction)
df3['Actual'] = df3.apply(actual_calc, axis=1)
df3.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume  \
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083   1.427083  18853200
# 5  1997-05-22  1.437500  1.447917  1.312500  1.395833   1.395833  11776800
# 6  1997-05-23  1.406250  1.520833  1.333333  1.500000   1.500000  15937200
# 7  1997-05-27  1.510417  1.645833  1.458333  1.583333   1.583333   8697600
# 8  1997-05-28  1.625000  1.635417  1.531250  1.531250   1.531250   4574400
# 9  1997-05-29  1.541667  1.541667  1.479167  1.505208   1.505208   3472800
#
#      Open 2     Max 7    Min 7    Change  Mean Change 7  Drop 7  Up 7  \
# 0  1.968750       NaN      NaN  0.468750            NaN     NaN   NaN
# ...

# %%
df3[df3['Prediction'] != df3['Actual']].shape
# Out:
# (3655, 17)

# %%
df3.shape
# Out:
# (5345, 17)

# %%
df3.dropna(subset=['Max 7', 'Min 7', 'Mean Change 7', 'Drop 7', 'Up 7'], inplace=True)

# %%
df3[df3.isnull().any(axis=1)].head(10)
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume, Open 2, Max 7, Min 7, Change, Mean Change 7, Drop 7, Up 7, Predict, Prediction, Actual]
# Index: []

# %%
df3.to_csv('data/AMZN-edited2.csv', index=False)
