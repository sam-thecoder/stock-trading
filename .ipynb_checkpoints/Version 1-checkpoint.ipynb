# %%
import pandas as pd
# %matplotlib inline

# %%
from game import choose_df, stock_game, player_2, main_key, game_record, predictions, past_predictions, player_3

# %%
df = choose_df()
# Out:
# Available options: "bitcoin, netflix, microsoft, tesla, google, disney, V, 3M, amazon, apple, facebook"
# Please Specify the name of the dataframe: bitcoin
# Dataframe set

# %%
df.head()
# Out:
#         Date  Value USD  Drop 7  Up 7   Min 7     Max 7    Mean 7  \
# 0  8/29/2010    0.06480     2.0   4.0  0.0648  0.066889  0.065813
# 1  8/30/2010    0.06900     1.0   5.0  0.0648  0.069000  0.066241
# 2  8/31/2010    0.06497     1.0   5.0  0.0648  0.069000  0.065967
# 3   9/1/2010    0.06490     1.0   5.0  0.0648  0.069000  0.065738
# 4   9/2/2010    0.06290     2.0   4.0  0.0629  0.069000  0.065224
#
#    Mean Change 7   Change  Predict
# 0      -0.000429 -0.00420       -2
# 1       0.000274  0.00403        2
# 2       0.000229  0.00007        2
# 3       0.000514  0.00200        2
# 4       0.000229 -0.00050       -1

# %%
#df[df['Date'] == '1/1/2018']

# %%
player_3(output=False, miss_plot=True, start_date='1/1/2018')
# Out:
# Reached the final day, game ending
# day: 8/6/2018 profit: 0 loss: 0.734349262121448 amount: 660.2833935348347 invested: 21.33434926212145

# %%
player_3(output=False, miss_plot=True)
# Out:
# You have 727.2 invested, you want to withdraw 1027.948007299304 which exceeds the amount available, try again with a smaller amount
# Reached the final day, game ending
# day: 8/6/2018 profit: 0 loss: 258375.57425815985 amount: 232721919.09876847 invested: 7519133.58425816

# %%
player_3(output=False, miss_plot=True, start_date='1/1/2017')
# Out:
# Reached the final day, game ending
# day: 8/6/2018 profit: 0 loss: 4.989760121705757 amount: 4496.844152819358 invested: 145.28976012170577

# %%
player_3(output=False, plot=True, start_date='1/1/2018')
# Out:
# Reached the final day, game ending
# day: 8/6/2018 profit: 0 loss: 0.734349262121448 amount: 660.2833935348347 invested: 21.33434926212145
# c:\users\samuel\appdata\local\programs\python\python35\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
player_3(output=False, plot=True)
# Out:
# You have 727.2 invested, you want to withdraw 1027.948007299304 which exceeds the amount available, try again with a smaller amount
# Reached the final day, game ending
# day: 8/6/2018 profit: 0 loss: 258375.57425815985 amount: 232721919.09876847 invested: 7519133.58425816
# c:\users\samuel\appdata\local\programs\python\python35\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
player_3(output=False, plot=True, start_date='1/1/2017')
# Out:
# Reached the final day, game ending
# day: 8/6/2018 profit: 0 loss: 4.989760121705757 amount: 4496.844152819358 invested: 145.28976012170577
# c:\users\samuel\appdata\local\programs\python\python35\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
player_2(output=False, plot=True)
# Out:
# Ups in Week 0 Downs in week 1 Days with Profit 0 Days with Loss 0
# Ups in Week 1 Downs in week 1 Days with Profit 0 Days with Loss 1
# Ups in Week 2 Downs in week 1 Days with Profit 0 Days with Loss 2
# Ups in Week 3 Downs in week 1 Days with Profit 0 Days with Loss 3
# Ups in Week 3 Downs in week 2 Days with Profit 1 Days with Loss 0
# Ups in Week 3 Downs in week 3 Days with Profit 2 Days with Loss 0
# Ups in Week 3 Downs in week 4 Days with Profit 0 Days with Loss 1
# Ups in Week 0 Downs in week 0 Days with Profit 1 Days with Loss 0
# Ups in Week 0 Downs in week 1 Days with Profit 2 Days with Loss 0
# Ups in Week 1 Downs in week 1 Days with Profit 0 Days with Loss 1
# Ups in Week 2 Downs in week 1 Days with Profit 0 Days with Loss 2
# Ups in Week 2 Downs in week 2 Days with Profit 1 Days with Loss 0
# Ups in Week 3 Downs in week 2 Days with Profit 0 Days with Loss 1
# Ups in Week 3 Downs in week 3 Days with Profit 1 Days with Loss 0
# ...

# %%
player_2(output=False, miss_plot=True)
# Out:
# Reached the final day, game ending
# day: 08/08/2018 profit: 19.5814921907 loss: 0 amount: 1608.91657028 invested: 7174.70850781

# %%
player_2(output=False, plot=True)
# Out:
# Reached the final day, game ending
# day: 08/08/2018 profit: 0 loss: 67.137266757 amount: 3102.54540081 invested: 2761.11726676

# %%
player_2(output=False, miss_plot=True)
# Out:
# Reached the final day, game ending
# day: 08/08/2018 profit: 0 loss: 67.137266757 amount: 3102.54540081 invested: 2761.11726676

# %%
player_2(output=False, plot=True)
# Out:
# Reached the final day, game ending
# day: 08/01/2018 profit: 0 loss: 160.111856567 amount: 2882.7355697 invested: 30817.6418566

# %%
player_2(output=False, miss_plot=True)
# Out:
# Reached the final day, game ending
# day: 08/01/2018 profit: 0 loss: 160.111856567 amount: 2882.7355697 invested: 30817.6418566

# %%
player_2(output=False, plot=True)
# Out:
# Reached the final day, game ending
# day: 08/08/2018 profit: 19.5814921907 loss: 0 amount: 1608.91657028 invested: 7174.70850781

# %%
player_2(output=False, miss_plot=True)
# Out:
# Reached the final day, game ending
# day: 08/08/2018 profit: 19.5814921907 loss: 0 amount: 1608.91657028 invested: 7174.70850781

# %%
player_2(output=False, plot=True)
# Out:
# ('Ups in Week', 0, 'Downs in week', 1, 'Days with Profit', 0, 'Days with Loss', 0)
# Reached the final day, game ending
# day: 08/08/2018 profit: 539.036749764 loss: 0 amount: 148022.709751 invested: 797432.22325

# %%
player_2(output=False, miss_output=True)
# Out:
# ('Ups in Week', 0, 'Downs in week', 1, 'Days with Profit', 0, 'Days with Loss', 0)
# loss day: 03/03/1981 profit: 0 loss: 10.713398313 amount: 99.3154386125 invested: 781.275146204 predict: 0
# loss day: 04/24/1981 profit: 0 loss: 6.14 amount: 161.346220777 invested: 728.647357864 predict: 0
# loss day: 07/20/1981 profit: 0 loss: 46.0366078336 amount: 228.788841151 invested: 659.71098235 predict: 0
# loss day: 08/06/1981 profit: 0 loss: 20.7129381974 amount: 63.9423328326 invested: 858.054110944 predict: 0
# loss day: 02/04/1982 profit: 0 loss: 14.6570413316 amount: 140.932011595 invested: 594.769112399 predict: 0
# loss day: 04/02/1982 profit: 0 loss: 0.00493947289283 amount: 111.550336577 invested: 585.774481842 predict: 0
# loss day: 04/05/1982 profit: 0 loss: 0.0044818418678 amount: 83.6627524326 invested: 613.657584144 predict: 0
# loss day: 05/10/1982 profit: 0 loss: 8.24769411884 amount: 101.351774121 invested: 540.821308236 predict: 0
# ...

# %%
player_2(output=False, miss_plot=True)
# Out:
# ('Ups in Week', 0, 'Downs in week', 1, 'Days with Profit', 0, 'Days with Loss', 0)
# Reached the final day, game ending
# day: 08/08/2018 profit: 539.036749764 loss: 0 amount: 148022.709751 invested: 797432.22325

# %%
player_2(output=True, start_date='01/02/2018')
# Out:
# ('Ups in Week', 0, 'Downs in week', 1, 'Days with Profit', 0, 'Days with Loss', 0)
# day: 01/04/2018 profit: 0 loss: 0 amount: 500 invested: 500 predict: -2
# day: 01/08/2018 profit: 0 loss: 2.34 amount: 338 invested: 665.35 predict: -1
# day: 01/10/2018 profit: 0 loss: 0.17 amount: 328.927 invested: 674.173 predict: -2
# day: 01/12/2018 profit: 7.84825 loss: 0 amount: 222.025725 invested: 792.749525 predict: -1
# day: 01/17/2018 profit: 13.94356875 loss: 0 amount: 250.941936875 invested: 773.747356875 predict: -2
# day: 01/19/2018 profit: 0 loss: 3.73548421875 amount: 169.385807391 invested: 852.260645266 predict: 0
# day: 01/23/2018 profit: 0.19 loss: 0 amount: 253.914807391 invested: 760.951 predict: 2
# day: 01/24/2018 profit: 0 loss: 12.121 amount: 190.436105543 invested: 812.308701848 predict: 2
# day: 01/26/2018 profit: 1.86 loss: 0 amount: 270.217105543 invested: 719.889 predict: 2
# ...

# %%
df[df['Date'] == '04/30/1981']
# Out:
#           Date  Value USD  Drop 7  Up 7     Min 7    Max 7    Mean 7  \
# 89  04/30/1981   0.022884     2.0   4.0  0.022481  0.02359  0.023042
#
#     Mean Change 7  Change  Predict
# 89       0.000014     0.0       -1

# %%
df[df.index == 9330]
# Out:
#             Date  Value USD  Drop 7  Up 7      Min 7       Max 7      Mean 7  \
# 9330  01/02/2018  170.30423     3.0   3.0  167.30864  173.023026  170.013299
#
#       Mean Change 7    Change  Predict
# 9330       0.392637  0.029663        1

# %%
player_2(output=False, start_date='01/02/2018', plot=True)
# Out:
# ('Ups in Week', 0, 'Downs in week', 1, 'Days with Profit', 0, 'Days with Loss', 0)
# Reached the final day, game ending
# day: 08/08/2018 profit: 0.753374460976 loss: 0 amount: 47.1198766171 invested: 1108.68662554

# %%
player_2(output=False, start_date='01/03/2017', plot=True)
# Out:
# ('Ups in Week', 0, 'Downs in week', 1, 'Days with Profit', 0, 'Days with Loss', 0)
# Reached the final day, game ending
# day: 08/08/2018 profit: 1.07103717478 loss: 0 amount: 67.3468884757 invested: 1582.18896283
